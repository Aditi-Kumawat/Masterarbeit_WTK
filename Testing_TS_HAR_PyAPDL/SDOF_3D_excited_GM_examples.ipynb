# %% [markdown]
# ### Example of SODF system excited by artificial ground motion
# - using MASS21 and COMBIN14 elements

# %% [markdown]
# - Generate artificial ground motion

# %%
import matlab.engine
import numpy as np
import matplotlib.pyplot as plt

# Start the matlab engine
eng = matlab.engine.start_matlab()
# Link to the dir of matlab function
eng.cd(r'C:\Users\v196m\Desktop\master_project\Masterarbeit\GroundMotion\GroundMotionGeneration', nargout=0)
#s = eng.genpath('\BaselineCorrection')
#eng.addpath(s, nargout=0)
#eng.cd(r'C:\Users\v196m\Desktop\master_project\Masterarbeit\GroundMotion\GroundMotionGeneration\BaselineCorrection', nargout=0)
# Parameter of GM setting
Start_Time = 0.005
End_time = 15.005
Time_interval = 0.005
Time =  np.arange(Start_Time, End_time, Time_interval)

Time_info = np.array([0.5,	4.51602635361311,	6.51382766164269,	10.8203132545630])
FRF_info  = np.array([85.634147247517, 0.364521248606246, 0.213591303771144])
AriasIntensity = 0.0000508679639647511

# Generate ground motion
time,acc,vel,disp = eng.fns_generateGM_Params(5,Time,100,"Hu_S0", FRF_info, Time_info, AriasIntensity,1, nargout=4)
acc_signal = np.column_stack((time, acc))
vel_signal = np.column_stack((time, vel))
disp_signal = np.column_stack((time, disp))

time_interval_transient = 0.005
n_time=int(((End_time-Start_Time)/time_interval_transient)+1)


# Create a figure and three subplots
fig, (ax1, ax2, ax3) = plt.subplots(3, 1, sharex=True, figsize=(8, 6))

# Plot on the first subplot
ax1.plot(np.array(time), np.array(acc), label='Acc(t)')
#ax1.set_ylabel('Amplitude')
ax1.legend()

# Plot on the second subplot
ax2.plot(np.array(time), np.array(vel), label='Vel(t)', color='orange')
#ax2.set_ylabel('Amplitude')
ax2.legend()

# Plot on the third subplot
ax3.plot(np.array(time), np.array(disp), label='Disp(t)', color='green')
ax3.set_xlabel('time (s)')
ax3.set_ylabel('Amplitude')
ax3.legend()

# Adjust layout
plt.tight_layout()

# Show the plot
plt.show()

# %% [markdown]
# - ANSYS SDOF system

# %%
from ansys.mapdl.core import launch_mapdl
mapdl = launch_mapdl(nproc=4)
# Out:
# PyMAPDL is taking longer than expected to connect to an MAPDL session.
# Checking if there are any available licenses...

# %%
mapdl.prep7()
mapdl.units("SI")  # SI - International system (m, kg, s, K).


# Create Node
mapdl.n(1,"0","0","0")
mapdl.n(2,"0","0","10")

# Define mass21 element 
mapdl.et(1, "MASS21", kop3=2)
mapdl.type(1)
mapdl.real(1)
mapdl.r(1,100)
mapdl.e(2)


mapdl.et(2, "COMBIN14", kop2=3)
mapdl.type(2)
mapdl.real(2)
k = (4*np.pi**2)*10000
mapdl.r(2,k,1000)
mapdl.e(1,2)


mapdl.nsel("ALL")
mapdl.allsel()
mapdl.nummrg("ALL")

mapdl.load_table("ACC_input", acc_signal ,"TIME")
mapdl.load_table("VEL_input", vel_signal ,"TIME")
mapdl.load_table("DISP_input", disp_signal ,"TIME")


#mapdl.eplot(
#    vtk=True,
#    show_node_numbering=True,
#    cpos="yz",
#    show_edges=True,
#    show_axes=True,
#    line_width=2,
#)

# %%
#mapdl.run("/SOLU")
#mapdl.antype(4)  # transient analysis
#mapdl.trnopt("FULL")  # full transient analysis
#
#mapdl.outres("ALL","NONE")	
#mapdl.outres("NSOL","1")
#mapdl.outres("EPFL")
#mapdl.outres("ESOL")
#mapdl.outres("RSOL")
#
#mapdl.eqslv("SPARSE")  # use sparse solver
#
#mapdl.dmprat("0.05")
#
#count = 0
#for i_time in range(n_time-1):
#    tval = (i_time+1)*time_interval_transient
#    mapdl.time(tval)
#    #print(mapdl.time("tval"))
#    mapdl.d("1","ACCZ","%ACC_input%")
#
#    mapdl.nsubst("1")
#    mapdl.allsel()
#    mapdl.solve()
#
#    if i_time == int(count*(n_time/20)):
#        print("SOLVING TRANSIENT ANAYLSIS: ",5*count, " %")
#        count = count + 1
#
#mapdl.exit()

# %% [markdown]
# - Testing another solving method

# %%
mapdl.run("/SOLU")
mapdl.antype(4)  # transient analysis
mapdl.trnopt("FULL")  # full transient analysis

mapdl.outres("ALL","NONE")	
mapdl.outres("NSOL","1")
#mapdl.outres("EPFL")
#mapdl.outres("ESOL")
#mapdl.outres("RSOL")
mapdl.outres("V","1")
mapdl.outres("A","1")

# Time stepping
end_time = End_time
mapdl.time(end_time)  # end time for load step
mapdl.autots("ON")  # use automatic time stepping
#mapdl.parameters["tsres_time"] = Time
#mapdl.tsres("%tsres_time%")

# setup where the subset time is 10 seconds, time
mapdl.deltim(0.001, 0.0005, 0.0015)  # substep size (seconds)
#                          -- minimum value shorter than smallest
#                            time change in the table arrays below

mapdl.eqslv("SPARSE")  # use sparse solver
mapdl.dmprat("0.05")
#mapdl.d("1","ACCZ","%ACC_input%")
mapdl.d("1","UZ","%DISP_input%")

mapdl.solve()
# Out:
# *** NOTE ***                            CP =       2.359   TIME= 20:30:37
#  The automatic domain decomposition logic has selected the MESH domain
#  decomposition method with 4 processes per solution.
#
#  *****  ANSYS SOLVE    COMMAND  *****
#
#  *** NOTE ***                            CP =       2.359   TIME= 20:30:37
#  There is no title defined for this analysis.
#
#  *** WARNING ***                         CP =       2.359   TIME= 20:30:37
#  Nodes I and J of element 2 ( COMBIN14 ) are not coincident.
#
#  *** NOTE ***                            CP =       2.359   TIME= 20:30:37
#  The model data was checked and warning messages were found.
#   Please review output or errors file (
#  C:\Users\v196m\AppData\Local\Temp\ansys_njwbbixltr\file0.err ) for
#  these warning messages.
#
#  *** ANSYS - ENGINEERING ANALYSIS SYSTEM  RELEASE 2021 R2          21.2     ***
#  DISTRIBUTED Ansys Mechanical Enterprise Academic Teaching
#
#  00000000  VERSION=WINDOWS x64   20:30:37  JAN 16, 2024 CP=      2.359
#
#
#
#
#
#                        S O L U T I O N   O P T I O N S
#
#    PROBLEM DIMENSIONALITY. . . . . . . . . . . . .3-D
#    DEGREES OF FREEDOM. . . . . . UX   UY   UZ
#    ANALYSIS TYPE . . . . . . . . . . . . . . . . .TRANSIENT
#       SOLUTION METHOD. . . . . . . . . . . . . . .FULL
#    EQUATION SOLVER OPTION. . . . . . . . . . . . .SPARSE
#    GLOBALLY ASSEMBLED MATRIX . . . . . . . . . . .SYMMETRIC
#
#  *** NOTE ***                            CP =       2.359   TIME= 20:30:37
#  The number of CPU processors specified is greater than the number of
#  elements selected in the model.  The number of Distributed ANSYS
#  processes will be reduced to 2 for this solution.
#
#
#
#      D I S T R I B U T E D   D O M A I N   D E C O M P O S E R
#
#   ...Number of elements: 2
#   ...Number of nodes:    2
#   ...Decompose to 2 CPU domains
#
#  *** NOTE ***                            CP =       2.359   TIME= 20:30:37
#  The program can optimally decompose the model into 2 domains, which
#  does not match the total number of processors specified upon startup
#  of Distributed ANSYS.  Distributed parallel processing has been
#  temporarily modified to only use 2 processes for this solution.
#   ...Element load balance ratio =     1.000
#
#
#                       L O A D   S T E P   O P T I O N S
#
#    LOAD STEP NUMBER. . . . . . . . . . . . . . . .     1
#    TIME AT END OF THE LOAD STEP. . . . . . . . . .  15.005
#    AUTOMATIC TIME STEPPING . . . . . . . . . . . .    ON
#       STARTING TIME STEP SIZE. . . . . . . . . . . 0.10000E-02
#       MINIMUM TIME STEP SIZE . . . . . . . . . . . 0.50000E-03
#       MAXIMUM TIME STEP SIZE . . . . . . . . . . . 0.15000E-02
#    STEP CHANGE BOUNDARY CONDITIONS . . . . . . . .   YES
#    TRANSIENT (INERTIA) EFFECTS
#       STRUCTURAL DOFS. . . . . . . . . . . . . . .    ON
#    TRANSIENT INTEGRATION PARAMETERS
#       ALPHA. . . . . . . . . . . . . . . . . . . . 0.25251
#       DELTA. . . . . . . . . . . . . . . . . . . . 0.50500
#    PRINT OUTPUT CONTROLS . . . . . . . . . . . . .NO PRINTOUT
#    DATABASE OUTPUT CONTROLS
#       ITEM     FREQUENCY   COMPONENT
#        ALL       NONE
#       NSOL        ALL
#       V           ALL
#       A           ALL
#
#
#  SOLUTION MONITORING INFO IS WRITTEN TO FILE= file.mntr
#
#
#
#                          ***********  PRECISE MASS SUMMARY  ***********
#
#    TOTAL RIGID BODY MASS MATRIX ABOUT ORIGIN
#                Translational mass               |   Coupled translational/rotational mass
#          100.00        0.0000        0.0000     |     0.0000        1000.0        0.0000
#          0.0000        100.00        0.0000     |    -1000.0        0.0000        0.0000
#          0.0000        0.0000        100.00     |     0.0000        0.0000        0.0000
#      ------------------------------------------ | ------------------------------------------
#                                                 |         Rotational mass (inertia)
#                                                 |     10000.        0.0000        0.0000
#                                                 |     0.0000        10000.        0.0000
#                                                 |     0.0000        0.0000        0.0000
#
#    TOTAL MASS =  100.00
#      The mass principal axes coincide with the global Cartesian axes
#
#    CENTER OF MASS (X,Y,Z)=    0.0000        0.0000        10.000
#
#    TOTAL INERTIA ABOUT CENTER OF MASS
#          0.0000        0.0000        0.0000
#          0.0000        0.0000        0.0000
#          0.0000        0.0000        0.0000
#      The inertia principal axes coincide with the global Cartesian axes
#
#
#   *** MASS SUMMARY BY ELEMENT TYPE ***
#
#   TYPE      MASS
#      1   100.000
#
#  Range of element maximum matrix coefficients in global coordinates
#  Maximum = 394784.176 at element 2.
#  Minimum = 394784.176 at element 2.
#
#    *** ELEMENT MATRIX FORMULATION TIMES
#      TYPE    NUMBER   ENAME      TOTAL CP  AVE CP
#
#         1         1  MASS21        0.000   0.000000
#         2         1  COMBIN14      0.000   0.000000
#  Time at end of element matrix formulation CP = 2.421875.
#
#  ALL CURRENT ANSYS DATA WRITTEN TO FILE NAME= file.rdb
#   FOR POSSIBLE RESUME FROM THIS POINT
#
#  DISTRIBUTED SPARSE MATRIX DIRECT SOLVER.
#   Number of equations =           3,    Maximum wavefront =      3
#
#   Local memory allocated for solver              =      0.176 MB
#   Local memory required for in-core solution     =      0.168 MB
#   Local memory required for out-of-core solution =      0.168 MB
#
#   Total memory allocated for solver              =      0.352 MB
#   Total memory required for in-core solution     =      0.335 MB
#   Total memory required for out-of-core solution =      0.335 MB
#
#  *** NOTE ***                            CP =       2.422   TIME= 20:30:37
#  The Distributed Sparse Matrix Solver is currently running in the
#  in-core memory mode.  This memory mode uses the most amount of memory
#  in order to avoid using the hard drive as much as possible, which most
#  often results in the fastest solution time.  This mode is recommended
#  if enough physical memory is present to accommodate all of the solver
#  data.
#  Distributed sparse solver maximum pivot= 398424536 at node 2 UZ.
#  Distributed sparse solver minimum pivot= 396029801 at node 2 UY.
#  Distributed sparse solver minimum pivot in absolute value= 396029801 at
#  node 2 UY.
#
#    *** ELEMENT RESULT CALCULATION TIMES
#      TYPE    NUMBER   ENAME      TOTAL CP  AVE CP
#
#         1         1  MASS21        0.000   0.000000
#         2         1  COMBIN14      0.000   0.000000
#
#    *** NODAL LOAD CALCULATION TIMES
#      TYPE    NUMBER   ENAME      TOTAL CP  AVE CP
#
#         1         1  MASS21        0.000   0.000000
#         2         1  COMBIN14      0.000   0.000000
#  *** LOAD STEP     1   SUBSTEP     1  COMPLETED.    CUM ITER =      1
#  *** TIME =  0.100000E-02     TIME INC =  0.100000E-02  NEW TRIANG MATRIX
#  *** AUTO STEP TIME:  NEXT TIME INC = 0.10000E-02  UNCHANGED
#
#  *** LOAD STEP     1   SUBSTEP     2  COMPLETED.    CUM ITER =      2
#  *** TIME =  0.200000E-02     TIME INC =  0.100000E-02  OLD TRIANG MATRIX
#  *** AUTO TIME STEP:  NEXT TIME INC = 0.15000E-02  INCREASED (FACTOR = 1.5000)
#
#  *** LOAD STEP     1   SUBSTEP     3  COMPLETED.    CUM ITER =      3
#  *** TIME =  0.350000E-02     TIME INC =  0.150000E-02  NEW TRIANG MATRIX
#  *** AUTO STEP TIME:  NEXT TIME INC = 0.15000E-02  UNCHANGED
#
#  *** LOAD STEP     1   SUBSTEP     4  COMPLETED.    CUM ITER =      4
#  *** TIME =  0.500000E-02     TIME INC =  0.150000E-02  OLD TRIANG MATRIX
#  *** AUTO STEP TIME:  NEXT TIME INC = 0.15000E-02  UNCHANGED
#
#  *** LOAD STEP     1   SUBSTEP     5  COMPLETED.    CUM ITER =      5
#  *** TIME =  0.650000E-02     TIME INC =  0.150000E-02  OLD TRIANG MATRIX
#  *** RESPONSE FREQ =  1019.       PERIOD=  0.9818E-03  PTS/CYC = 0.65
#  *** AUTO TIME STEP:  NEXT TIME INC = 0.75025E-03  DECREASED (FACTOR = 0.5002)
#
#  *** LOAD STEP     1   SUBSTEP     6  COMPLETED.    CUM ITER =      6
#  *** TIME =  0.725025E-02     TIME INC =  0.750250E-03  NEW TRIANG MATRIX
#  *** RESPONSE FREQ =  377.5       PERIOD=  0.2649E-02  PTS/CYC =  3.5
#  *** AUTO STEP TIME:  NEXT TIME INC = 0.75025E-03  UNCHANGED
#
#  *** LOAD STEP     1   SUBSTEP     7  COMPLETED.    CUM ITER =      7
#  *** TIME =  0.800050E-02     TIME INC =  0.750250E-03  OLD TRIANG MATRIX
#  *** RESPONSE FREQ =  242.3       PERIOD=  0.4127E-02  PTS/CYC =  5.5
#  *** AUTO STEP TIME:  NEXT TIME INC = 0.75025E-03  UNCHANGED
#
#  *** LOAD STEP     1   SUBSTEP     8  COMPLETED.    CUM ITER =      8
#  *** TIME =  0.875075E-02     TIME INC =  0.750250E-03  OLD TRIANG MATRIX
#  *** RESPONSE FREQ =  170.3       PERIOD=  0.5874E-02  PTS/CYC =  7.8
#  *** AUTO STEP TIME:  NEXT TIME INC = 0.75025E-03  UNCHANGED
#
#  *** LOAD STEP     1   SUBSTEP     9  COMPLETED.    CUM ITER =      9
#  *** TIME =  0.950100E-02     TIME INC =  0.750250E-03  OLD TRIANG MATRIX
#  *** RESPONSE FREQ =  126.4       PERIOD=  0.7909E-02  PTS/CYC =  11.
#  *** AUTO STEP TIME:  NEXT TIME INC = 0.75025E-03  UNCHANGED
#
#  *** LOAD STEP     1   SUBSTEP    10  COMPLETED.    CUM ITER =     10
#  *** TIME =  0.102513E-01     TIME INC =  0.750250E-03  OLD TRIANG MATRIX
#  *** RESPONSE FREQ =  164.0       PERIOD=  0.6097E-02  PTS/CYC =  8.1
#  *** AUTO STEP TIME:  NEXT TIME INC = 0.75025E-03  UNCHANGED
#
#  *** LOAD STEP     1   SUBSTEP    11  COMPLETED.    CUM ITER =     11
#  *** TIME =  0.110015E-01     TIME INC =  0.750250E-03  OLD TRIANG MATRIX
#  *** RESPONSE FREQ =  221.1       PERIOD=  0.4522E-02  PTS/CYC =  6.0
#  *** AUTO STEP TIME:  NEXT TIME INC = 0.75025E-03  UNCHANGED
#
#  *** LOAD STEP     1   SUBSTEP    12  COMPLETED.    CUM ITER =     12
#  *** TIME =  0.117518E-01     TIME INC =  0.750250E-03  OLD TRIANG MATRIX
#  *** RESPONSE FREQ =  162.5       PERIOD=  0.6154E-02  PTS/CYC =  8.2
#  *** AUTO STEP TIME:  NEXT TIME INC = 0.75025E-03  UNCHANGED
#
#  *** LOAD STEP     1   SUBSTEP    13  COMPLETED.    CUM ITER =     13
#  *** TIME =  0.125020E-01     TIME INC =  0.750250E-03  OLD TRIANG MATRIX
#  *** RESPONSE FREQ =  124.0       PERIOD=  0.8067E-02  PTS/CYC =  11.
#  *** AUTO STEP TIME:  NEXT TIME INC = 0.75025E-03  UNCHANGED
#
#  *** LOAD STEP     1   SUBSTEP    14  COMPLETED.    CUM ITER =     14
#  *** TIME =  0.132523E-01     TIME INC =  0.750250E-03  OLD TRIANG MATRIX
#  *** RESPONSE FREQ =  97.24       PERIOD=  0.1028E-01  PTS/CYC =  14.
#  *** AUTO TIME STEP:  NEXT TIME INC = 0.79107E-03  INCREASED (FACTOR = 1.0544)
#
#  *** LOAD STEP     1   SUBSTEP    15  COMPLETED.    CUM ITER =     15
#  *** TIME =  0.140433E-01     TIME INC =  0.791069E-03  NEW TRIANG MATRIX
#  *** RESPONSE FREQ =  77.47       PERIOD=  0.1291E-01  PTS/CYC =  16.
#  *** AUTO TIME STEP:  NEXT TIME INC = 0.99295E-03  INCREASED (FACTOR = 1.2552)
#
#  *** LOAD STEP     1   SUBSTEP    16  COMPLETED.    CUM ITER =     16
#  *** TIME =  0.150363E-01     TIME INC =  0.992950E-03  NEW TRIANG MATRIX
#  *** RESPONSE FREQ =  62.47       PERIOD=  0.1601E-01  PTS/CYC =  16.
#  *** AUTO TIME STEP:  NEXT TIME INC = 0.12313E-02  INCREASED (FACTOR = 1.2401)
#
#  *** LOAD STEP     1   SUBSTEP    17  COMPLETED.    CUM ITER =     17
#  *** TIME =  0.162676E-01     TIME INC =  0.123134E-02  NEW TRIANG MATRIX
#  *** RESPONSE FREQ =  80.74       PERIOD=  0.1239E-01  PTS/CYC =  10.
#  *** AUTO TIME STEP:  NEXT TIME INC = 0.95275E-03  DECREASED (FACTOR = 0.7738)
#
#  *** LOAD STEP     1   SUBSTEP    18  COMPLETED.    CUM ITER =     18
#  *** TIME =  0.172204E-01     TIME INC =  0.952752E-03  NEW TRIANG MATRIX
#  *** RESPONSE FREQ =  61.40       PERIOD=  0.1629E-01  PTS/CYC =  17.
#  *** AUTO STEP TIME:  NEXT TIME INC = 0.95275E-03  UNCHANGED
#
#  *** LOAD STEP     1   SUBSTEP    19  COMPLETED.    CUM ITER =     19
#  *** TIME =  0.181731E-01     TIME INC =  0.952752E-03  OLD TRIANG MATRIX
#  *** RESPONSE FREQ =  49.05       PERIOD=  0.2039E-01  PTS/CYC =  21.
#  *** AUTO TIME STEP:  NEXT TIME INC = 0.15000E-02  INCREASED (FACTOR = 1.5744)
#
#  *** LOAD STEP     1   SUBSTEP    20  COMPLETED.    CUM ITER =     20
#  *** TIME =  0.196731E-01     TIME INC =  0.150000E-02  NEW TRIANG MATRIX
#  *** RESPONSE FREQ =  37.30       PERIOD=  0.2681E-01  PTS/CYC =  18.
#  *** AUTO STEP TIME:  NEXT TIME INC = 0.15000E-02  UNCHANGED
#
#  *** LOAD STEP     1   SUBSTEP
+03
#  *** AUTO STEP TIME:  NEXT TIME INC = 0.15000E-02  UNCHANGED
#
#  *** LOAD STEP     1   SUBSTEP    69  COMPLETED.    CUM ITER =     69
#  *** TIME =  0.931731E-01     TIME INC =  0.150000E-02  OLD TRIANG MATRIX
#  *** RESPONSE FREQ = 0.7847       PERIOD=   1.274      PTS/CYC = 0.85E+03
#  *** AUTO STEP TIME:  NEXT TIME INC = 0.15000E-02  UNCHANGED
#
#  *** LOAD STEP     1   SUBSTEP    70  COMPLETED.    CUM ITER =     70
#  *** TIME =  0.946731E-01     TIME INC =  0.150000E-02  OLD TRIANG MATRIX
#  *** RESPONSE FREQ = 0.8547       PERIOD=   1.170      PTS/CYC = 0.78E+03
#  *** AUTO STEP TIME:  NEXT TIME INC = 0.15000E-02  UNCHANGED
#
#  *** LOAD STEP     1   SUBSTEP    71  COMPLETED.    CUM ITER =     71
#  *** TIME =  0.961731E-01     TIME INC =  0.150000E-02  OLD TRIANG MATRIX
#  *** RESPONSE FREQ = 0.5176       PERIOD=   1.932      PTS/CYC = 0.13E+04
#  *** AUTO STEP TIME:  NEXT TIME INC = 0.15000E-02  UNCHANGED
#
#  *** LOAD STEP     1   SUBSTEP    72  COMPLETED.    CUM ITER =     72
#  *** TIME =  0.976731E-01     TIME INC =  0.150000E-02  OLD TRIANG MATRIX
#  *** RESPONSE FREQ = 0.4707       PERIOD=   2.125      PTS/CYC = 0.14E+04
#  *** AUTO STEP TIME:  NEXT TIME INC = 0.15000E-02  UNCHANGED
#
#  *** LOAD STEP     1   SUBSTEP    73  COMPLETED.    CUM ITER =     73
#  *** TIME =  0.991731E-01     TIME INC =  0.150000E-02  OLD TRIANG MATRIX
#  *** RESPONSE FREQ = 0.5306       PERIOD=   1.885      PTS/CYC = 0.13E+04
#  *** AUTO STEP TIME:  NEXT TIME INC = 0.15000E-02  UNCHANGED
#
#  *** LOAD STEP     1   SUBSTEP    74  COMPLETED.    CUM ITER =     74
#  *** TIME =  0.100673         TIME INC =  0.150000E-02  OLD TRIANG MATRIX
#  *** RESPONSE FREQ = 0.3606       PERIOD=   2.773      PTS/CYC = 0.18E+04
#  *** AUTO STEP TIME:  NEXT TIME INC = 0.15000E-02  UNCHANGED
#
#  *** LOAD STEP     1   SUBSTEP    75  COMPLETED.    CUM ITER =     75
#  *** TIME =  0.102173         TIME INC =  0.150000E-02  OLD TRIANG MATRIX
#  *** RESPONSE FREQ = 0.1411       PERIOD=   7.085      PTS/CYC = 0.47E+04
#  *** AUTO STEP TIME:  NEXT TIME INC = 0.15000E-02  UNCHANGED
#
#  *** LOAD STEP     1   SUBSTEP    76  COMPLETED.    CUM ITER =     76
#  *** TIME =  0.103673         TIME INC =  0.150000E-02  OLD TRIANG MATRIX
#  *** RESPONSE FREQ = 0.1979       PERIOD=   5.054      PTS/CYC = 0.34E+04
#  *** AUTO STEP TIME:  NEXT TIME INC = 0.15000E-02  UNCHANGED
#
#  *** LOAD STEP     1   SUBSTEP    77  COMPLETED.    CUM ITER =     77
#  *** TIME =  0.105173         TIME INC =  0.150000E-02  OLD TRIANG MATRIX
#  *** RESPONSE FREQ = 0.1949       PERIOD=   5.130      PTS/CYC = 0.34E+04
#  *** AUTO STEP TIME:  NEXT TIME INC = 0.15000E-02  UNCHANGED
#
#  *** LOAD STEP     1   SUBSTEP    78  COMPLETED.    CUM ITER =     78
#  *** TIME =  0.106673         TIME INC =  0.150000E-02  OLD TRIANG MATRIX
#  *** RESPONSE FREQ = 0.1841       PERIOD=   5.431      PTS/CYC = 0.36E+04
#  *** AUTO STEP TIME:  NEXT TIME INC = 0.15000E-02  UNCHANGED
#
#  *** LOAD STEP     1   SUBSTEP    79  COMPLETED.    CUM ITER =     79
#  *** TIME =  0.108173         TIME INC =  0.150000E-02  OLD TRIANG MATRIX
#  *** RESPONSE FREQ = 0.1235       PERIOD=   8.099      PTS/CYC = 0.54E+04
#  *** AUTO STEP TIME:  NEXT TIME INC = 0.15000E-02  UNCHANGED
#
#  *** LOAD STEP     1   SUBSTEP    80  COMPLETED.    CUM ITER =     80
#  *** TIME =  0.109673         TIME INC =  0.150000E-02  OLD TRIANG MATRIX
#  *** RESPONSE FREQ = 0.6335E-01   PERIOD=   15.79      PTS/CYC = 0.11E+05
#  *** AUTO STEP TIME:  NEXT TIME INC = 0.15000E-02  UNCHANGED
#
#  *** LOAD STEP     1   SUBSTEP    81  COMPLETED.    CUM ITER =     81
#  *** TIME =  0.111173         TIME INC =  0.150000E-02  OLD TRIANG MATRIX
#  *** RESPONSE FREQ = 0.3777       PERIOD=   2.648      PTS/CYC = 0.18E+04
#  *** AUTO STEP TIME:  NEXT TIME INC = 0.15000E-02  UNCHANGED
#
#  *** LOAD STEP     1   SUBSTEP    82  COMPLETED.    CUM ITER =     82
#  *** TIME =  0.112673         TIME INC =  0.150000E-02  OLD TRIANG MATRIX
#  *** RESPONSE FREQ = 0.4122       PERIOD=   2.426      PTS/CYC = 0.16E+04
#  *** AUTO STEP TIME:  NEXT TIME INC = 0.15000E-02  UNCHANGED
#
#  *** LOAD STEP     1   SUBSTEP    83  COMPLETED.    CUM ITER =     83
#  *** TIME =  0.114173         TIME INC =  0.150000E-02  OLD TRIANG MATRIX
#  *** RESPONSE FREQ = 0.3394       PERIOD=   2.946      PTS/CYC = 0.20E+04
#  *** AUTO STEP TIME:  NEXT TIME INC = 0.15000E-02  UNCHANGED
#
#  *** LOAD STEP     1   SUBSTEP    84  COMPLETED.    CUM ITER =     84
#  *** TIME =  0.115673         TIME INC =  0.150000E-02  OLD TRIANG MATRIX
#  *** RESPONSE FREQ = 0.4751       PERIOD=   2.105      PTS/CYC = 0.14E+04
#  *** AUTO STEP TIME:  NEXT TIME INC = 0.15000E-02  UNCHANGED
#
#  *** LOAD STEP     1   SUBSTEP    85  COMPLETED.    CUM ITER =     85
#  *** TIME =  0.117173         TIME INC =  0.150000E-02  OLD TRIANG MATRIX
#  *** RESPONSE FREQ = 0.6497       PERIOD=   1.539      PTS/CYC = 0.10E+04
#  *** AUTO STEP TIME:  NEXT TIME INC = 0.15000E-02  UNCHANGED
#
#  *** LOAD STEP     1   SUBSTEP    86  COMPLETED.    CUM ITER =     86
#  *** TIME =  0.118673         TIME INC =  0.150000E-02  OLD TRIANG MATRIX
#  *** RESPONSE FREQ = 0.5596       PERIOD=   1.787      PTS/CYC = 0.12E+04
#  *** AUTO STEP TIME:  NEXT TIME INC = 0.15000E-02  UNCHANGED
#
#  *** LOAD STEP     1   SUBSTEP    87  COMPLETED.    CUM ITER =     87
#  *** TIME =  0.120173         TIME INC =  0.150000E-02  OLD TRIANG MATRIX
#  *** RESPONSE FREQ = 0.5196       PERIOD=   1.924      PTS/CYC = 0.13E+04
#  *** AUTO STEP TIME:  NEXT TIME INC = 0.15000E-02  UNCHANGED
#
#  *** LOAD STEP     1   SUBSTEP    88  COMPLETED.    CUM ITER =     88
#  *** TIME =  0.121673         TIME INC =  0.150000E-02  OLD TRIANG MATRIX
#  *** RESPONSE FREQ = 0.8225       PERIOD=   1.216      PTS/CYC = 0.81E+03
#  *** AUTO STEP TIME:  NEXT TIME INC = 0.15000E-02  UNCHANGED
#
#  *** LOAD STEP     1   SUBSTEP    89  COMPLETED.    CUM ITER =     89
#  *** TIME =  0.123173         TIME INC =  0.150000E-02  OLD TRIANG MATRIX
#  *** RESPONSE FREQ = 0.7127       PERIOD=   1.403      PTS/CYC = 0.94E+03
#  *** AUTO STEP TIME:  NEXT TIME INC = 0.15000E-02  UNCHANGED
#
#  *** LOAD STEP     1   SUBSTEP    90  COMPLETED.    CUM ITER =     90
#  *** TIME =  0.124673         TIME INC =  0.150000E-02  OLD TRIANG MATRIX
#  *** RESPONSE FREQ = 0.6001       PERIOD=   1.666      PTS/CYC = 0.11E+04
#  *** AUTO STEP TIME:  NEXT TIME INC = 0.15000E-02  UNCHANGED
#
#  *** LOAD STEP     1   SUBSTEP    91  COMPLETED.    CUM ITER =     91
#  *** TIME =  0.126173         TIME INC =  0.150000E-02  OLD TRIANG MATRIX
#  *** RESPONSE FREQ = 0.8267       PERIOD=   1.210      PTS/CYC = 0.81E+03
#  *** AUTO STEP TIME:  NEXT TIME INC = 0.15000E-02  UNCHANGED
#
#  *** LOAD STEP     1   SUBSTEP    92  COMPLETED.    CUM ITER =     92
#  *** TIME =  0.127673         TIME INC =  0.150000E-02  OLD TRIANG MATRIX
#  *** RESPONSE FREQ = 0.7938       PERIOD=   1.260      PTS/CYC = 0.84E+03
#  *** AUTO STEP TIME:  NEXT TIME INC = 0.15000E-02  UNCHANGED
#
#  *** LOAD STEP     1   SUBSTEP    93  COMPLETED.    CUM ITER =     93
#  *** TIME =  0.129173         TIME INC =  0.150000E-02  OLD TRIANG MATRIX
#  *** RESPONSE FREQ = 0.6620       PERIOD=   1.511      PTS/CYC = 0.10E+04
#  *** AUTO STEP TIME:  NEXT TIME INC = 0.15000E-02  UNCHANGED
#
#  *** LOAD STEP     1   SUBSTEP    94  COMPLETED.    CUM ITER =     94
#  *** TIME =  0.130673         TIME INC =  0.150000E-02  OLD TRIANG MATRIX
#  *** RESPONSE FREQ = 0.7174       PERIOD=   1.394      PTS/CYC = 0.93E+03
#  *** AUTO STEP TIME:  NEXT TIME INC = 0.15000E-02  UNCHANGED
#
#  *** LOAD STEP     1   SUBSTEP    95  COMPLETED.    CUM ITER =     95
#  *** TIME =  0.132173         TIME INC =  0.150000E-02  OLD TRIANG MATRIX
#  *** RESPONSE FREQ = 0.8062       PERIOD=   1.240      PTS/CYC = 0.83E+03
#  *** AUTO STEP TIME:  NEXT TIME INC = 0.15000E-02  UNCHANGED
#
#  *** LOAD STEP     1   SUBSTEP    96  COMPLETED.    CUM ITER =     96
#  *** TIME =  0.133673         TIME INC =  0.150000E-02  OLD TRIANG MATRIX
#  *** RESPONSE FREQ = 0.6585       PERIOD=   1.519      PTS/CYC = 0.10E+04
#  *** AUTO STEP TIME:  NEXT TIME INC = 0.15000E-02  UNCHANGED
#
#  *** LOAD STEP     1   SUBSTEP    97  COMPLETED.    CUM ITER =     97
#  *** TIME =  0.135173         TIME INC =  0.150000E-02  OLD TRIANG MATRIX
#  *** RESPONSE FREQ = 0.5572       PERIOD=   1.795      PTS/CYC = 0.12E+04
#  *** AUTO STEP TIME:  NEXT TIME INC = 0.15000E-02  UNCHANGED
#
#  *** LOAD STEP     1   SUBSTEP    98  COMPLETED.    CUM ITER =     98
#  *** TIME =  0.136673         TIME INC =  0.150000E-02  OLD TRIANG MATRIX
#  *** RESPONSE FREQ = 0.7600       PERIOD=   1.316      PTS/CYC = 0.88E+03
#  *** AUTO STEP TIME:  NEXT TIME INC = 0.15000E-02  UNCHANGED
#
#  *** LOAD STEP     1   SUBSTEP    99  COMPLETED.    CUM ITER =     99
#  *** TIME =  0.138173         TIME INC =  0.150000E-02  OLD TRIANG MATRIX
#  *** RESPONSE FREQ = 0.6012       PERIOD=   1.663      PTS/CYC = 0.11E+04
#  *** AUTO STEP TIME:  NEXT TIME INC = 0.15000E-02  UNCHANGED
#
#  *** LOAD STEP     1   SUBSTEP   100  COMPLETED.    CUM ITER =    100
#  *** TIME =  0.139673         TIME INC =  0.150000E-02  OLD TRIANG MATRIX
#  *** RESPONSE FREQ = 0.4438       PERIOD=   2.253      PTS/CYC = 0.15E+04
#  *** AUTO STEP TIME:  NEXT TIME INC = 0.15000E-02  UNCHANGED
#
#  *** LOAD STEP     1   SUBSTEP   101  COMPLETED.    CUM ITER =    101
#  *** TIME =  0.141173         TIME INC =  0.150000E-02  OLD TRIANG MATRIX
#  *** RESPONSE FREQ = 0.5854       PERIOD=   1.708      PTS/CYC = 0.11E+04
#  *** AUTO STEP TIME:  NEXT TIME INC = 0.15000E-02  UNCHANGED
#
#  *** LOAD STEP     1   SUBSTEP   102  COMPLETED.    CUM ITER =    102
#  *** TIME =  0.142673         TIME INC =  0.150000E-02  OLD TRIANG MATRIX
#  *** RESPONSE FREQ = 0.5048       PERIOD=   1.981      PTS/CYC = 0.13E+04
#  *** AUTO STEP TIME:  NEXT TIME INC = 0.15000E-02  UNCHANGED
#
#  *** LOAD STEP     1   SUBSTEP   103  COMPLETED.    CUM ITER =    103
#  *** TIME =  0.144173         TIME INC =  0.150000E-02  OLD TRIANG MATRIX
#  *** RESPONSE FREQ = 0.3432       PERIOD=   2.914      PTS/CYC = 0.19E+04
#  *** AUTO STEP TIME:  NEXT TIME INC = 0.15000E-02  UNCHANGED
#
#  *** LOAD STEP     1   SUBSTEP   104  COMPLETED.    CUM ITER =    104
#  *** TIME =  0.145673         TIME INC =  0.150000E-02  OLD TRIANG MATRIX
#  *** RESPONSE FREQ = 0.3477       PERIOD=   2.876      PTS/CYC = 0.19E+04
#  *** AUTO STEP TIME:  NEXT TIME INC = 0.15000E-02  UNCHANGED
#
#  *** LOAD STEP     1   SUBSTEP   105  COMPLETED.    CUM ITER =    105
#  *** TIME =  0.147173         TIME INC =  0.150000E-02  OLD TRIANG MATRIX
#  *** RESPONSE FREQ = 0.3853       PERIOD=   2.595      PTS/CYC = 0.17E+04
#  *** AUTO STEP TIME:  NEXT TIME INC = 0.15000E-02  UNCHANGED
#
#  *** LOAD STEP     1   SUBSTEP   106  COMPLETED.    CUM ITER =    106
#  *** TIME =  0.148673         TIME INC =  0.150000E-02  OLD TRIANG MATRIX
#  *** RESPONSE FREQ = 0.2248       PERIOD=   4.448      PTS/CYC = 0.30E+04
#  *** AUTO STEP TIME:  NEXT TIME INC = 0.15000E-02  UNCHANGED
#
#  *** LOAD STEP     1   SUBSTEP   107  COMPLETED.    CUM ITER =    107
#  *** TIME =  0.150173         TIME INC =  0.150000E-02  OLD TRIANG MATRIX
#  *** RESPONSE FREQ = 0.1092       PERIOD=   9.157      PTS/CYC = 0.61E+04
#  *** AUTO STEP TIME:  NEXT TIME INC = 0.15000E-02  UNCHANGED
#
#  *** LOAD STEP     1   SUBSTEP   108  COMPLETED.    CUM ITER =    108
#  *** TIME =  0.151673         TIME INC =  0.150000E-02  OLD TRIANG MATRIX
#  *** RESPONSE FREQ = 0.2585       PERIOD=   3.868      PTS/CYC = 0.26E+04
#  *** AUTO STEP TIME:  NEXT TIME INC = 0.15000E-02  UNCHANGED
#
#  *** LOAD STEP     1   SUBSTEP   109  COMPLETED.    CUM ITER =    109
#  *** TIME =  0.153173         TIME INC =  0.150000E-02  OLD TRIANG MATRIX
#  *** RESPONSE FREQ = 0.1035       PERIOD=   9.658      PTS/CYC = 0.64E+04
#  *** AUTO STEP TIME:  NEXT TIME INC = 0.15000E-02  UNCHANGED
#
#  *** LOAD STEP     1   SUBSTEP   110  COMPLETED.    CUM ITER =    110
#  *** TIME =  0.154673         TIME INC =  0.150000E-02  OLD TRIANG MATRIX
#  *** RESPONSE FREQ = 0.4554E-01   PERIOD=   21.96      PTS/CYC = 0.15E+05
#  *** AUTO STEP TIME:  NEXT TIME INC = 0.15000E-02  UNCHANGED
#
#  *** LOAD STEP     1   SUBSTEP   111  COMPLETED.    CUM ITER =    111
#  *** TIME =  0.156173         TIME INC =  0.150000E-02  OLD TRIANG MATRIX
#  *** RESPONSE FREQ = 0.6554E-01   PERIOD=   15.26      PTS/CYC = 0.10E+05
#  *** AUTO STEP TIME:  NEXT TIME INC = 0.15000E-02  UNCHANGED
#
#  *** LOAD STEP     1   SUBSTEP   112  COMPLETED.    CUM ITER =    112
#  *** TIME =  0.157673         TIME INC =  0.150000E-02  OLD TRIANG MATRIX
#  *** RESPONSE FREQ = 0.8830E-02   PERIOD=   113.2      PTS/CYC = 0.75E+05
#  *** AUTO STEP TIME:  NEXT TIME INC = 0.15000E-02  UNCHANGED
#
#  *** LOAD STEP     1   SUBSTEP   113  COMPLETED.    CUM ITER =    113
#  *** TIME =  0.159173         TIME INC =  0.150000E-02  OLD TRIANG MATRIX
#  *** RESPONSE FREQ = 0.1485       PERIOD=   6.732      PTS/CYC = 0.45E+04
#  *** AUTO STEP TIME:  NEXT TIME INC = 0.15000E-02  UNCHANGED
#
#  *** LOAD STEP     1   SUBSTEP   114  COMPLETED.    CUM ITER =    114
#  *** TIME =  0.160673         TIME INC =  0.150000E-02  OLD TRIANG MATRIX
#  *** RESPONSE FREQ = 0.1419       PERIOD=   7.045      PTS/CYC = 0.47E+04
#  *** AUTO STEP TIME:  NEXT TIME INC = 0.15000E-02  UNCHANGED
#
#  *** LOAD STEP     1   SUBSTEP   115  COMPLETED.    CUM ITER =    115
#  *** TIME =  0.162173         TIME INC =  0.150000E-02  OLD TRIANG MATRIX
#  *** RESPONSE FREQ = 0.1030       PERIOD=   9.707      PTS/CYC = 0.65E+04
#  *** AUTO STEP TIME:  NEXT TIME INC = 0.15000E-02  UNCHANGED
#
#  *** LOAD STEP     1   SUBSTEP   116  COMPLETED.    CUM ITER =    116
#  *** TIME =  0.163673         TIME INC =  0.150000E-02  OLD TRIANG MATRIX
#  *** RESPONSE FREQ = 0.2313       PERIOD=   4.324      PTS/CYC = 0.29E+04
#  *** AUTO STEP TIME:  NEXT TIME INC = 0.15000E-02  UNCHANGED
#
#  *** LOAD STEP     1   SUBSTEP   117  COMPLETED.    CUM ITER =    117
#  *** TIME =  0.165173         TIME INC =  0.150000E-02  OLD TRIANG MATRIX
#  *** RESPONSE FREQ = 0
#  *** AUTO STEP TIME:  NEXT TIME INC = 0.15000E-02  UNCHANGED
#
#  *** LOAD STEP     1   SUBSTEP   142  COMPLETED.    CUM ITER =    142
#  *** TIME =  0.202673         TIME INC =  0.150000E-02  OLD TRIANG MATRIX
#  *** RESPONSE FREQ = 0.4675E-01   PERIOD=   21.39      PTS/CYC = 0.14E+05
#  *** AUTO STEP TIME:  NEXT TIME INC = 0.15000E-02  UNCHANGED
#
#  *** LOAD STEP     1   SUBSTEP   143  COMPLETED.    CUM ITER =    143
#  *** TIME =  0.204173         TIME INC =  0.150000E-02  OLD TRIANG MATRIX
#  *** RESPONSE FREQ = 0.9194E-01   PERIOD=   10.88      PTS/CYC = 0.73E+04
#  *** AUTO STEP TIME:  NEXT TIME INC = 0.15000E-02  UNCHANGED
#
#  *** LOAD STEP     1   SUBSTEP   144  COMPLETED.    CUM ITER =    144
#  *** TIME =  0.205673         TIME INC =  0.150000E-02  OLD TRIANG MATRIX
#  *** RESPONSE FREQ = 0.2675E-01   PERIOD=   37.39      PTS/CYC = 0.25E+05
#  *** AUTO STEP TIME:  NEXT TIME INC = 0.15000E-02  UNCHANGED
#
#  *** LOAD STEP     1   SUBSTEP   145  COMPLETED.    CUM ITER =    145
#  *** TIME =  0.207173         TIME INC =  0.150000E-02  OLD TRIANG MATRIX
#  *** RESPONSE FREQ = 0.6181E-01   PERIOD=   16.18      PTS/CYC = 0.11E+05
# ...
#  *** AUTO STEP TIME:  NEXT TIME INC = 0.15000E-02  UNCHANGED
#
#  *** LOAD STEP     1   SUBSTEP 10264  COMPLETED.    CUM ITER =  10264
#  *** TIME =   14.9233         TIME INC =  0.150000E-02  OLD TRIANG MATRIX
#  *** RESPONSE FREQ =  7.273       PERIOD=  0.1375      PTS/CYC =  92.
#  *** AUTO STEP TIME:  NEXT TIME INC = 0.15000E-02  UNCHANGED
#
#  *** LOAD STEP     1   SUBSTEP 10265  COMPLETED.    CUM ITER =  10265
#  *** TIME =   14.9248         TIME INC =  0.150000E-02  OLD TRIANG MATRIX
#  *** RESPONSE FREQ =  7.344       PERIOD=  0.1362      PTS/CYC =  91.
#  *** AUTO STEP TIME:  NEXT TIME INC = 0.15000E-02  UNCHANGED
#
#  *** LOAD STEP     1   SUBSTEP 10266  COMPLETED.    CUM ITER =  10266
#  *** TIME =   14.9263         TIME INC =  0.150000E-02  OLD TRIANG MATRIX
#  *** RESPONSE FREQ =  7.249       PERIOD=  0.1379      PTS/CYC =  92.
#  *** AUTO STEP TIME:  NEXT TIME INC = 0.15000E-02  UNCHANGED
#
#  *** LOAD STEP     1   SUBSTEP 10267  COMPLETED.    CUM ITER =  10267
#  *** TIME =   14.9278         TIME INC =  0.150000E-02  OLD TRIANG MATRIX
#  *** RESPONSE FREQ =  7.264       PERIOD=  0.1377      PTS/CYC =  92.
#  *** AUTO STEP TIME:  NEXT TIME INC = 0.15000E-02  UNCHANGED
#
#  *** LOAD STEP     1   SUBSTEP 10268  COMPLETED.    CUM ITER =  10268
#  *** TIME =   14.9293         TIME INC =  0.150000E-02  OLD TRIANG MATRIX
#  *** RESPONSE FREQ =  7.279       PERIOD=  0.1374      PTS/CYC =  92.
#  *** AUTO STEP TIME:  NEXT TIME INC = 0.15000E-02  UNCHANGED
#
#  *** LOAD STEP     1   SUBSTEP 10269  COMPLETED.    CUM ITER =  10269
#  *** TIME =   14.9308         TIME INC =  0.150000E-02  OLD TRIANG MATRIX
#  *** RESPONSE FREQ =  7.148       PERIOD=  0.1399      PTS/CYC =  93.
#  *** AUTO STEP TIME:  NEXT TIME INC = 0.15000E-02  UNCHANGED
#
#  *** LOAD STEP     1   SUBSTEP 10270  COMPLETED.    CUM ITER =  10270
#  *** TIME =   14.9323         TIME INC =  0.150000E-02  OLD TRIANG MATRIX
#  *** RESPONSE FREQ =  7.022       PERIOD=  0.1424      PTS/CYC =  95.
#  *** AUTO STEP TIME:  NEXT TIME INC = 0.15000E-02  UNCHANGED
#
#  *** LOAD STEP     1   SUBSTEP 10271  COMPLETED.    CUM ITER =  10271
#  *** TIME =   14.9338         TIME INC =  0.150000E-02  OLD TRIANG MATRIX
#  *** RESPONSE FREQ =  6.983       PERIOD=  0.1432      PTS/CYC =  95.
#  *** AUTO STEP TIME:  NEXT TIME INC = 0.15000E-02  UNCHANGED
#
#  *** LOAD STEP     1   SUBSTEP 10272  COMPLETED.    CUM ITER =  10272
#  *** TIME =   14.9353         TIME INC =  0.150000E-02  OLD TRIANG MATRIX
#  *** RESPONSE FREQ =  6.818       PERIOD=  0.1467      PTS/CYC =  98.
#  *** AUTO STEP TIME:  NEXT TIME INC = 0.15000E-02  UNCHANGED
#
#  *** LOAD STEP     1   SUBSTEP 10273  COMPLETED.    CUM ITER =  10273
#  *** TIME =   14.9368         TIME INC =  0.150000E-02  OLD TRIANG MATRIX
#  *** RESPONSE FREQ =  6.342       PERIOD=  0.1577      PTS/CYC = 0.11E+03
#  *** AUTO STEP TIME:  NEXT TIME INC = 0.15000E-02  UNCHANGED
#
#  *** LOAD STEP     1   SUBSTEP 10274  COMPLETED.    CUM ITER =  10274
#  *** TIME =   14.9383         TIME INC =  0.150000E-02  OLD TRIANG MATRIX
#  *** RESPONSE FREQ =  6.228       PERIOD=  0.1606      PTS/CYC = 0.11E+03
#  *** AUTO STEP TIME:  NEXT TIME INC = 0.15000E-02  UNCHANGED
#
#  *** LOAD STEP     1   SUBSTEP 10275  COMPLETED.    CUM ITER =  10275
#  *** TIME =   14.9398         TIME INC =  0.150000E-02  OLD TRIANG MATRIX
#  *** RESPONSE FREQ =  6.086       PERIOD=  0.1643      PTS/CYC = 0.11E+03
#  *** AUTO STEP TIME:  NEXT TIME INC = 0.15000E-02  UNCHANGED
#
#  *** LOAD STEP     1   SUBSTEP 10276  COMPLETED.    CUM ITER =  10276
#  *** TIME =   14.9413         TIME INC =  0.150000E-02  OLD TRIANG MATRIX
#  *** RESPONSE FREQ =  4.970       PERIOD=  0.2012      PTS/CYC = 0.13E+03
#  *** AUTO STEP TIME:  NEXT TIME INC = 0.15000E-02  UNCHANGED
#
#  *** LOAD STEP     1   SUBSTEP 10277  COMPLETED.    CUM ITER =  10277
#  *** TIME =   14.9428         TIME INC =  0.150000E-02  OLD TRIANG MATRIX
#  *** RESPONSE FREQ =  4.594       PERIOD=  0.2177      PTS/CYC = 0.15E+03
#  *** AUTO STEP TIME:  NEXT TIME INC = 0.15000E-02  UNCHANGED
#
#  *** LOAD STEP     1   SUBSTEP 10278  COMPLETED.    CUM ITER =  10278
#  *** TIME =   14.9443         TIME INC =  0.150000E-02  OLD TRIANG MATRIX
#  *** RESPONSE FREQ =  4.299       PERIOD=  0.2326      PTS/CYC = 0.16E+03
#  *** AUTO STEP TIME:  NEXT TIME INC = 0.15000E-02  UNCHANGED
#
#  *** LOAD STEP     1   SUBSTEP 10279  COMPLETED.    CUM ITER =  10279
#  *** TIME =   14.9458         TIME INC =  0.150000E-02  OLD TRIANG MATRIX
#  *** RESPONSE FREQ =  2.864       PERIOD=  0.3492      PTS/CYC = 0.23E+03
#  *** AUTO STEP TIME:  NEXT TIME INC = 0.15000E-02  UNCHANGED
#
#  *** LOAD STEP     1   SUBSTEP 10280  COMPLETED.    CUM ITER =  10280
#  *** TIME =   14.9473         TIME INC =  0.150000E-02  OLD TRIANG MATRIX
#  *** RESPONSE FREQ =  1.456       PERIOD=  0.6868      PTS/CYC = 0.46E+03
#  *** AUTO STEP TIME:  NEXT TIME INC = 0.15000E-02  UNCHANGED
#
#  *** LOAD STEP     1   SUBSTEP 10281  COMPLETED.    CUM ITER =  10281
#  *** TIME =   14.9488         TIME INC =  0.150000E-02  OLD TRIANG MATRIX
#  *** RESPONSE FREQ = 0.8725       PERIOD=   1.146      PTS/CYC = 0.76E+03
#  *** AUTO STEP TIME:  NEXT TIME INC = 0.15000E-02  UNCHANGED
#
#  *** LOAD STEP     1   SUBSTEP 10282  COMPLETED.    CUM ITER =  10282
#  *** TIME =   14.9503         TIME INC =  0.150000E-02  OLD TRIANG MATRIX
#  *** RESPONSE FREQ = 0.3777       PERIOD=   2.648      PTS/CYC = 0.18E+04
#  *** AUTO STEP TIME:  NEXT TIME INC = 0.15000E-02  UNCHANGED
#
#  *** LOAD STEP     1   SUBSTEP 10283  COMPLETED.    CUM ITER =  10283
#  *** TIME =   14.9518         TIME INC =  0.150000E-02  OLD TRIANG MATRIX
#  *** RESPONSE FREQ =  3.429       PERIOD=  0.2917      PTS/CYC = 0.19E+03
#  *** AUTO STEP TIME:  NEXT TIME INC = 0.15000E-02  UNCHANGED
#
#  *** LOAD STEP     1   SUBSTEP 10284  COMPLETED.    CUM ITER =  10284
#  *** TIME =   14.9533         TIME INC =  0.150000E-02  OLD TRIANG MATRIX
#  *** RESPONSE FREQ =  4.414       PERIOD=  0.2265      PTS/CYC = 0.15E+03
#  *** AUTO STEP TIME:  NEXT TIME INC = 0.15000E-02  UNCHANGED
#
#  *** LOAD STEP     1   SUBSTEP 10285  COMPLETED.    CUM ITER =  10285
#  *** TIME =   14.9548         TIME INC =  0.150000E-02  OLD TRIANG MATRIX
#  *** RESPONSE FREQ =  5.473       PERIOD=  0.1827      PTS/CYC = 0.12E+03
#  *** AUTO STEP TIME:  NEXT TIME INC = 0.15000E-02  UNCHANGED
#
#  *** LOAD STEP     1   SUBSTEP 10286  COMPLETED.    CUM ITER =  10286
#  *** TIME =   14.9563         TIME INC =  0.150000E-02  OLD TRIANG MATRIX
#  *** RESPONSE FREQ =  9.102       PERIOD=  0.1099      PTS/CYC =  73.
#  *** AUTO STEP TIME:  NEXT TIME INC = 0.15000E-02  UNCHANGED
#
#  *** LOAD STEP     1   SUBSTEP 10287  COMPLETED.    CUM ITER =  10287
#  *** TIME =   14.9578         TIME INC =  0.150000E-02  OLD TRIANG MATRIX
#  *** RESPONSE FREQ =  10.66       PERIOD=  0.9382E-01  PTS/CYC =  63.
#  *** AUTO STEP TIME:  NEXT TIME INC = 0.15000E-02  UNCHANGED
#
#  *** LOAD STEP     1   SUBSTEP 10288  COMPLETED.    CUM ITER =  10288
#  *** TIME =   14.9593         TIME INC =  0.150000E-02  OLD TRIANG MATRIX
#  *** RESPONSE FREQ =  11.80       PERIOD=  0.8476E-01  PTS/CYC =  57.
#  *** AUTO STEP TIME:  NEXT TIME INC = 0.15000E-02  UNCHANGED
#
#  *** LOAD STEP     1   SUBSTEP 10289  COMPLETED.    CUM ITER =  10289
#  *** TIME =   14.9608         TIME INC =  0.150000E-02  OLD TRIANG MATRIX
#  *** RESPONSE FREQ =  13.67       PERIOD=  0.7316E-01  PTS/CYC =  49.
#  *** AUTO STEP TIME:  NEXT TIME INC = 0.15000E-02  UNCHANGED
#
#  *** LOAD STEP     1   SUBSTEP 10290  COMPLETED.    CUM ITER =  10290
#  *** TIME =   14.9623         TIME INC =  0.150000E-02  OLD TRIANG MATRIX
#  *** RESPONSE FREQ =  15.18       PERIOD=  0.6587E-01  PTS/CYC =  44.
#  *** AUTO STEP TIME:  NEXT TIME INC = 0.15000E-02  UNCHANGED
#
#  *** LOAD STEP     1   SUBSTEP 10291  COMPLETED.    CUM ITER =  10291
#  *** TIME =   14.9638         TIME INC =  0.150000E-02  OLD TRIANG MATRIX
#  *** RESPONSE FREQ =  15.64       PERIOD=  0.6393E-01  PTS/CYC =  43.
#  *** AUTO STEP TIME:  NEXT TIME INC = 0.15000E-02  UNCHANGED
#
#  *** LOAD STEP     1   SUBSTEP 10292  COMPLETED.    CUM ITER =  10292
#  *** TIME =   14.9653         TIME INC =  0.150000E-02  OLD TRIANG MATRIX
#  *** RESPONSE FREQ =  15.58       PERIOD=  0.6420E-01  PTS/CYC =  43.
#  *** AUTO STEP TIME:  NEXT TIME INC = 0.15000E-02  UNCHANGED
#
#  *** LOAD STEP     1   SUBSTEP 10293  COMPLETED.    CUM ITER =  10293
#  *** TIME =   14.9668         TIME INC =  0.150000E-02  OLD TRIANG MATRIX
#  *** RESPONSE FREQ =  14.71       PERIOD=  0.6798E-01  PTS/CYC =  45.
#  *** AUTO STEP TIME:  NEXT TIME INC = 0.15000E-02  UNCHANGED
#
#  *** LOAD STEP     1   SUBSTEP 10294  COMPLETED.    CUM ITER =  10294
#  *** TIME =   14.9683         TIME INC =  0.150000E-02  OLD TRIANG MATRIX
#  *** RESPONSE FREQ =  14.20       PERIOD=  0.7041E-01  PTS/CYC =  47.
#  *** AUTO STEP TIME:  NEXT TIME INC = 0.15000E-02  UNCHANGED
#
#  *** LOAD STEP     1   SUBSTEP 10295  COMPLETED.    CUM ITER =  10295
#  *** TIME =   14.9698         TIME INC =  0.150000E-02  OLD TRIANG MATRIX
#  *** RESPONSE FREQ =  13.44       PERIOD=  0.7443E-01  PTS/CYC =  50.
#  *** AUTO STEP TIME:  NEXT TIME INC = 0.15000E-02  UNCHANGED
#
#  *** LOAD STEP     1   SUBSTEP 10296  COMPLETED.    CUM ITER =  10296
#  *** TIME =   14.9713         TIME INC =  0.150000E-02  OLD TRIANG MATRIX
#  *** RESPONSE FREQ =  9.546       PERIOD=  0.1048      PTS/CYC =  70.
#  *** AUTO STEP TIME:  NEXT TIME INC = 0.15000E-02  UNCHANGED
#
#  *** LOAD STEP     1   SUBSTEP 10297  COMPLETED.    CUM ITER =  10297
#  *** TIME =   14.9728         TIME INC =  0.150000E-02  OLD TRIANG MATRIX
#  *** RESPONSE FREQ =  8.338       PERIOD=  0.1199      PTS/CYC =  80.
#  *** AUTO STEP TIME:  NEXT TIME INC = 0.15000E-02  UNCHANGED
#
#  *** LOAD STEP     1   SUBSTEP 10298  COMPLETED.    CUM ITER =  10298
#  *** TIME =   14.9743         TIME INC =  0.150000E-02  OLD TRIANG MATRIX
#  *** RESPONSE FREQ =  7.482       PERIOD=  0.1337      PTS/CYC =  89.
#  *** AUTO STEP TIME:  NEXT TIME INC = 0.15000E-02  UNCHANGED
#
#  *** LOAD STEP     1   SUBSTEP 10299  COMPLETED.    CUM ITER =  10299
#  *** TIME =   14.9758         TIME INC =  0.150000E-02  OLD TRIANG MATRIX
#  *** RESPONSE FREQ =  4.208       PERIOD=  0.2377      PTS/CYC = 0.16E+03
#  *** AUTO STEP TIME:  NEXT TIME INC = 0.15000E-02  UNCHANGED
#
#  *** LOAD STEP     1   SUBSTEP 10300  COMPLETED.    CUM ITER =  10300
#  *** TIME =   14.9773         TIME INC =  0.150000E-02  OLD TRIANG MATRIX
#  *** RESPONSE FREQ =  1.658       PERIOD=  0.6030      PTS/CYC = 0.40E+03
#  *** AUTO STEP TIME:  NEXT TIME INC = 0.15000E-02  UNCHANGED
#
#  *** LOAD STEP     1   SUBSTEP 10301  COMPLETED.    CUM ITER =  10301
#  *** TIME =   14.9788         TIME INC =  0.150000E-02  OLD TRIANG MATRIX
#  *** RESPONSE FREQ =  1.155       PERIOD=  0.8659      PTS/CYC = 0.58E+03
#  *** AUTO STEP TIME:  NEXT TIME INC = 0.15000E-02  UNCHANGED
#
#  *** LOAD STEP     1   SUBSTEP 10302  COMPLETED.    CUM ITER =  10302
#  *** TIME =   14.9803         TIME INC =  0.150000E-02  OLD TRIANG MATRIX
#  *** RESPONSE FREQ = 0.1281       PERIOD=   7.807      PTS/CYC = 0.52E+04
#  *** AUTO STEP TIME:  NEXT TIME INC = 0.15000E-02  UNCHANGED
#
#  *** LOAD STEP     1   SUBSTEP 10303  COMPLETED.    CUM ITER =  10303
#  *** TIME =   14.9818         TIME INC =  0.150000E-02  OLD TRIANG MATRIX
#  *** RESPONSE FREQ =  3.358       PERIOD=  0.2978      PTS/CYC = 0.20E+03
#  *** AUTO STEP TIME:  NEXT TIME INC = 0.15000E-02  UNCHANGED
#
#  *** LOAD STEP     1   SUBSTEP 10304  COMPLETED.    CUM ITER =  10304
#  *** TIME =   14.9833         TIME INC =  0.150000E-02  OLD TRIANG MATRIX
#  *** RESPONSE FREQ =  3.555       PERIOD=  0.2813      PTS/CYC = 0.19E+03
#  *** AUTO STEP TIME:  NEXT TIME INC = 0.15000E-02  UNCHANGED
#
#  *** LOAD STEP     1   SUBSTEP 10305  COMPLETED.    CUM ITER =  10305
#  *** TIME =   14.9848         TIME INC =  0.150000E-02  OLD TRIANG MATRIX
#  *** RESPONSE FREQ =  3.720       PERIOD=  0.2688      PTS/CYC = 0.18E+03
#  *** AUTO STEP TIME:  NEXT TIME INC = 0.15000E-02  UNCHANGED
#
#  *** LOAD STEP     1   SUBSTEP 10306  COMPLETED.    CUM ITER =  10306
#  *** TIME =   14.9863         TIME INC =  0.150000E-02  OLD TRIANG MATRIX
#  *** RESPONSE FREQ =  6.177       PERIOD=  0.1619      PTS/CYC = 0.11E+03
#  *** AUTO STEP TIME:  NEXT TIME INC = 0.15000E-02  UNCHANGED
#
#  *** LOAD STEP     1   SUBSTEP 10307  COMPLETED.    CUM ITER =  10307
#  *** TIME =   14.9878         TIME INC =  0.150000E-02  OLD TRIANG MATRIX
#  *** RESPONSE FREQ =  6.527       PERIOD=  0.1532      PTS/CYC = 0.10E+03
#  *** AUTO STEP TIME:  NEXT TIME INC = 0.15000E-02  UNCHANGED
#
#  *** LOAD STEP     1   SUBSTEP 10308  COMPLETED.    CUM ITER =  10308
#  *** TIME =   14.9893         TIME INC =  0.150000E-02  OLD TRIANG MATRIX
#  *** RESPONSE FREQ =  6.546       PERIOD=  0.1528      PTS/CYC = 0.10E+03
#  *** AUTO STEP TIME:  NEXT TIME INC = 0.15000E-02  UNCHANGED
#
#  *** LOAD STEP     1   SUBSTEP 10309  COMPLETED.    CUM ITER =  10309
#  *** TIME =   14.9908         TIME INC =  0.150000E-02  OLD TRIANG MATRIX
#  *** RESPONSE FREQ =  7.564       PERIOD=  0.1322      PTS/CYC =  88.
#  *** AUTO STEP TIME:  NEXT TIME INC = 0.15000E-02  UNCHANGED
#
#  *** LOAD STEP     1   SUBSTEP 10310  COMPLETED.    CUM ITER =  10310
#  *** TIME =   14.9923         TIME INC =  0.150000E-02  OLD TRIANG MATRIX
#  *** RESPONSE FREQ =  8.384       PERIOD=  0.1193      PTS/CYC =  80.
#  *** AUTO STEP TIME:  NEXT TIME INC = 0.15000E-02  UNCHANGED
#
#  *** LOAD STEP     1   SUBSTEP 10311  COMPLETED.    CUM ITER =  10311
#  *** TIME =   14.9938         TIME INC =  0.150000E-02  OLD TRIANG MATRIX
#  *** RESPONSE FREQ =  8.357       PERIOD=  0.1197      PTS/CYC =  80.
#  *** AUTO STEP TIME:  NEXT TIME INC = 0.15000E-02  UNCHANGED
#
#  *** LOAD STEP     1   SUBSTEP 10312  COMPLETED.    CUM ITER =  10312
#  *** TIME =   14.9953         TIME INC =  0.150000E-02  OLD TRIANG MATRIX
#  *** RESPONSE FREQ =  8.587       PERIOD=  0.1165      PTS/CYC =  78.
#  *** AUTO STEP TIME:  NEXT TIME INC = 0.15000E-02  UNCHANGED
#
#  *** LOAD STEP     1   SUBSTEP 10313  COMPLETED.    CUM ITER =  10313
#  *** TIME =   14.9968         TIME INC =  0.150000E-02  OLD TRIANG MATRIX
#  *** RESPONSE FREQ =  9.552       PERIOD=  0.1047      PTS/CYC =  70.
#  *** AUTO STEP TIME:  NEXT TIME INC = 0.15000E-02  UNCHANGED
#
#  *** LOAD STEP     1   SUBSTEP 10314  COMPLETED.    CUM ITER =  10314
#  *** TIME =   14.9983         TIME INC =  0.150000E-02  OLD TRIANG MATRIX
#  *** RESPONSE FREQ =  9.532       PERIOD=  0.1049      PTS/CYC =  70.
#  *** AUTO STEP TIME:  NEXT TIME INC = 0.15000E-02  UNCHANGED
#
#  *** LOAD STEP     1   SUBSTEP 10315  COMPLETED.    CUM ITER =  10315
#  *** TIME =   14.9998         TIME INC =  0.150000E-02  OLD TRIANG MATRIX
#  *** RESPONSE FREQ =  9.506       PERIOD=  0.1052      PTS/CYC =  70.
#  *** AUTO STEP TIME:  NEXT TIME INC = 0.15000E-02  UNCHANGED
#
#  *** LOAD STEP     1   SUBSTEP 10316  COMPLETED.    CUM ITER =  10316
#  *** TIME =   15.0013         TIME INC =  0.150000E-02  OLD TRIANG MATRIX
#  *** RESPONSE FREQ =  9.938       PERIOD=  0.1006      PTS/CYC =  67.
#  *** AUTO STEP TIME:  NEXT TIME INC = 0.15000E-02  UNCHANGED
#
#  *** LOAD STEP     1   SUBSTEP 10317  COMPLETED.    CUM ITER =  10317
#  *** TIME =   15.0028         TIME INC =  0.150000E-02  OLD TRIANG MATRIX
#  *** RESPONSE FREQ =  10.00       PERIOD=  0.1000      PTS/CYC =  67.
#  *** AUTO STEP TIME:  NEXT TIME INC = 0.15000E-02  UNCHANGED
#
#  *** LOAD STEP     1   SUBSTEP 10318  COMPLETED.    CUM ITER =  10318
#  *** TIME =   15.0043         TIME INC =  0.150000E-02  OLD TRIANG MATRIX
#  *** RESPONSE FREQ =  10.00       PERIOD=  0.1000      PTS/CYC =  67.
#  *** AUTO TIME STEP:  NEXT TIME INC = 0.67486E-03  DECREASED (FACTOR = 0.4499)
#
#  *** LOAD STEP     1   SUBSTEP 10319  COMPLETED.    CUM ITER =  10319
#  *** TIME =   15.0050         TIME INC =  0.674860E-03  NEW TRIANG MATRIX
#  *** RESPONSE FREQ =  10.00       PERIOD=  0.1000      PTS/CYC = 0.15E+03
#
#
#  *** ANSYS BINARY FILE STATISTICS
#   BUFFER SIZE USED= 16384
#         0.062 MB WRITTEN ON ELEMENT MATRIX FILE: file0.emat
#         0.062 MB WRITTEN ON ELEMENT SAVED DATA FILE: file0.esav
#         0.062 MB WRITTEN ON ASSEMBLED MATRIX FILE: file0.full
#        25.625 MB WRITTEN ON RESULTS FILE: file0.rst

# %% [markdown]
# - Postprossesor

# %%
mapdl.post26()
acc_z_EG = mapdl.nsol("2","1","U","Z")
acc_z_1F = mapdl.nsol("3","2","U","Z")


time_values = mapdl.post_processing.time_values


plt.plot(time_values,acc_z_1F, label="ACC 1F")
plt.plot(time_values,acc_z_EG, label="ACC EG")
#plt.plot(time_values, label="ACC time")
plt.legend()
plt.xlabel("Time (seconds)")
plt.ylabel("ACC")
plt.show()

# %%
mapdl.exit()
